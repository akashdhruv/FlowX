# %%
# Sample API
import mae6225
mae6225.__version__
# Out:
# '0.1.dev'

# %%
# Define grid parameters
ivar = 0
rvar = 1
asol = 2
eror = 3

center_vars = 4

nx = 50
ny = 50

xmin = 0
xmax = 1

ymin = 0
ymax = 1

grid = mae6225.Grid(center_vars,nx,ny,xmin,xmax,ymin,ymax)

# %%
# Calculate the exact solution 
mae6225.poisson.getAnalytical(grid,asol)

# %%
# Plot the exact solution
mae6225.IO.plotContour(grid,asol)

# %%
# Calculate the RHS
mae6225.poisson.getRHS(grid,rvar)

# %%
# Plot RHS
mae6225.IO.plotContour(grid,rvar)

# %%
# Solve Poisson equation
iterations,residual = mae6225.poisson.solveJacobi(grid,ivar,rvar,5000,1e-12)

# %%
# Check iterations
iterations
# Out:
# 1052

# %%
# Check residual
residual
# Out:
# 9.96160080948645e-13

# %%
# Plot the numerical solution
mae6225.IO.plotContour(grid,ivar)

# %%
# Calculate error
mae6225.poisson.getError(grid,eror,ivar,asol)

# %%
# Plot error
mae6225.IO.plotContour(grid,eror)
