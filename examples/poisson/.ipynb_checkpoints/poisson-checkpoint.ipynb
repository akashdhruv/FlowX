# %%
# Sample API
import flowx
import simulation
flowx.__version__
# Out:
# '0.1.dev'

# %%
# Define grid parameters
nx, ny = 40, 40
xmin, xmax = 0.0, 1.0
ymin, ymax = 0.0, 1.0

# Define cell-centered variable names
center_vars = ['asol', 'ivar1','ivar2', 'rvar', 'eror']

# Define boundary condition for the poisson test
user_bc = 'neumann'

# Define boundary conditions for variable ivar
bc_type = {'ivar': [user_bc, user_bc, user_bc, user_bc]}
bc_val  = {'ivar': [0.0, 0.0, 0.0, 0.0]}

# Create the grid and data
grid = flowx.Grid('cell-centered', center_vars,
                    nx, ny, xmin, xmax, ymin, ymax,
                    user_bc_type=bc_type, user_bc_val=bc_val)

# %%
# Compute the analytical solution 
simulation.get_analytical(grid, 'asol', user_bc)

# %%
# Plot the analytical solution
flowx.io.plot_contour(grid, 'asol')

# %%
# Calculate the right-hand side of the Poisson system
simulation.get_rhs(grid, 'rvar', user_bc)

# %%
# Plot the right-hand side of the Poisson system
flowx.io.plot_contour(grid, 'rvar')

# %%
# Solve the Poisson system with Jacobi method
ites, res = flowx.poisson.solve_jacobi(grid, 'ivar1', 'rvar',
                                         maxiter=10000, tol=1e-9, verbose=True)
# Out:
# Jacobi method:
# - Number of iterations: 1267
# - Final residual: 9.976258787425213e-10

# %%
# Plot the numerical solution
flowx.io.plot_contour(grid, 'ivar1')

# %%
# Compute the error (absolute value of the difference)
grid.get_error('eror', 'ivar1', 'asol')

# %%
# Plot the error
flowx.io.plot_contour(grid, 'eror')

# %%
# Compute the L2-norm of the error.
l2_norm = grid.get_l2_norm('eror')

# %%
l2_norm
# Out:
# 2.5659207098760422e-05

# %%
# Solve the Poisson System with Gauss-Seidel method
ites, res = flowx.poisson.solve_gauss_seidel(grid, 'ivar2', 'rvar', maxiter=10000, tol=1e-9, verbose=True)
# Out:
# Gauss-Seidel method:
# - Number of iterations: 1267
# - Final residual: 9.976258787425213e-10

# %%
flowx.io.plot_contour(grid, 'ivar2')

# %%
# Compute the error (absolute value of the difference)
grid.get_error('eror', 'ivar2', 'asol')

# %%
# Plot the error
flowx.io.plot_contour(grid, 'eror')

# %%
# Compute the L2-norm of the error.
l2_norm = grid.get_l2_norm('eror')

# %%
l2_norm
# Out:
# 2.5659207098760422e-05
